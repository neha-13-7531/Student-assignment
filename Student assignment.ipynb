# %% [markdown]
# # **Pandas**
#
# # **What is Pandas ?**
# ***The pandas is library in python .which is used for data loading and data manipulating and data analysis.***
#
# - **There are two types of data structure mainly supported by pandas**
#
# **1.Series - 1-D array(list,tuple,set,dictionary).**
#
# **2.DataFrame - 2-D table like excel work sheet.**
#
# # **How to install pandas ?**
# - use pip install pandas as pd

# %% [markdown]
# **import library**

# %%
import pandas as pd # pandas use for loading  and manipulating the data

# %%
# load the dataset
df=pd.read_csv("C:\\Users\\Abc\\Downloads\\student_dataset.csv") 
df
# Out:
#      StudentID    Name  Gender           Course  Age  Marks Grade       City
# 0         2001    Isha  Female     Data Science   27     82     F  Bangalore
# 1         2002   Aarav  Female     Data Science   27     42     A  Hyderabad
# 2         2003  Vivaan    Male  Web Development   24     98     B    Kolkata
# 3         2004   Sanya  Female  Web Development   23     52     A  Hyderabad
# 4         2005   Anaya  Female  Web Development   28     51     A  Hyderabad
# ..         ...     ...     ...              ...  ...    ...   ...        ...
# 145       2146   Anaya    Male  Cloud Computing   19     44     B  Bangalore
# 146       2147   Meera  Female          AI & ML   18     57     D  Hyderabad
# 147       2148   Kabir  Female  Cloud Computing   21     92     F  Bangalore
# 148       2149   Sanya  Female   Cyber Security   26     60     D      Delhi
# 149       2150    Diya  Female          AI & ML   24     44     F      Delhi
#
# [150 rows x 8 columns]

# %% [markdown]
# **1.head()** : ***To get first 5 rows in dataset.***

# %%
df.head() # to get first 5 rows in data set
# Out:
#    StudentID    Name  Gender           Course  Age  Marks Grade       City
# 0       2001    Isha  Female     Data Science   27     82     F  Bangalore
# 1       2002   Aarav  Female     Data Science   27     42     A  Hyderabad
# 2       2003  Vivaan    Male  Web Development   24     98     B    Kolkata
# 3       2004   Sanya  Female  Web Development   23     52     A  Hyderabad
# 4       2005   Anaya  Female  Web Development   28     51     A  Hyderabad

# %% [markdown]
# **2.tail.()** : ***To get last 5 rows in dataset.***

# %%
df.tail() # to get last 5 rows
# Out:
#      StudentID   Name  Gender           Course  Age  Marks Grade       City
# 145       2146  Anaya    Male  Cloud Computing   19     44     B  Bangalore
# 146       2147  Meera  Female          AI & ML   18     57     D  Hyderabad
# 147       2148  Kabir  Female  Cloud Computing   21     92     F  Bangalore
# 148       2149  Sanya  Female   Cyber Security   26     60     D      Delhi
# 149       2150   Diya  Female          AI & ML   24     44     F      Delhi

# %% [markdown]
# **3.describe(include='all')** :***To summarize the data both numerical and texual column.***

# %%
df.describe(include='all') # to describe the data both categorical and numerical
# Out:
#           StudentID   Name Gender        Course         Age       Marks Grade  \
# count    150.000000    150    150           150  150.000000  150.000000   150
# unique          NaN     10      2             5         NaN         NaN     5
# top             NaN  Anaya   Male  Data Science         NaN         NaN     A
# freq            NaN     21     77            36         NaN         NaN    36
# mean    2075.500000    NaN    NaN           NaN   24.346667   67.033333   NaN
# std       43.445368    NaN    NaN           NaN    3.701962   17.598206   NaN
# min     2001.000000    NaN    NaN           NaN   18.000000   40.000000   NaN
# 25%     2038.250000    NaN    NaN           NaN   21.250000   52.000000   NaN
# 50%     2075.500000    NaN    NaN           NaN   24.000000   62.000000   NaN
# 75%     2112.750000    NaN    NaN           NaN   27.000000   82.750000   NaN
# max     2150.000000    NaN    NaN           NaN   30.000000  100.000000   NaN
#
#              City
# ...

# %% [markdown]
# **Name**
#
# - count : The total count of name is 150 this show there is no missing value in this column.
# - unique : In Name 10 unique values are present.
# - top : The Anaya is most repeated name in the column.
# - frequency : The Anaya is 21 times are repeated.
#
# **Gender**
# - count : The total count of Gender is 150 this show there is some missing values in this column.
# - unique : In Gender 2 unique values are present.(Male and Female)
# - top : The Male is most repeated Gender in the column.
# - frequency : The Male Gender  is 77 times are repeated.
#
# **Course**
# - count : The total count of Course is 150 this show there is no missing values in this column.
# - unique : In Course 5 unique values are present.
# - top : The Data Science is most repeated name in the column.
# - frequency : The Data Science is 77 times are repeated.
#
# **City**
# - count : The total count of  city is 150 this show there is no missing values in this column.
# - unique : In city column 5 unique cities are present.
# - top : The Bangalore is most repeated name in the column.
# - frequency : The Bangalore is 48 times are repeated.

# %%
df.describe() # to get summary of numerical column
# Out:
#          StudentID         Age       Marks
# count   150.000000  150.000000  150.000000
# mean   2075.500000   24.346667   67.033333
# std      43.445368    3.701962   17.598206
# min    2001.000000   18.000000   40.000000
# 25%    2038.250000   21.250000   52.000000
# 50%    2075.500000   24.000000   62.000000
# 75%    2112.750000   27.000000   82.750000
# max    2150.000000   30.000000  100.000000

# %% [markdown]
# **Age**
# - mean : The average (mean) Age column is 24.34 .
# - std : The standard deviation is 3.70 is less than mean i.e the data values are closer to mean, or around the mean.
# - min : The smallest value is 18.
# - max : The largest value is 30.
# - 25 % (Q1): The 25 % value is 21.25 that show the values below the 25 % of the data fall.
# - 50 % (median): The middle value of this age column is 24.
# - 75 % (Q3) : 75 % of the product are price at or below 27 with only the high 25 % price above this.
#
# **Marks**
# - count : The Marks column has 150  entries .i.e there is no missing value in marks colmn
# - mean : The average is 67.033 .
# - std : The standard deviation is 17.59 which is less than mean i.e the data values are closer to mean, or around the mean.
# - min : The minimum marks is 40.
# - 25 % (Q1) : The value is 52 that show the values below the 25 % of the data fall.
# - 50 % (median): The middle value of marks column is 62.
# - 75 % (Q3) : 75 % of marks at or below 82 with only the high 25 % price above this.
# - max : The heigest marks is 100.

# %% [markdown]
# **5.shape** : ***To give total number of rows and columns.***

# %%
df.shape # shows the number of rows and column
# Out:
# (150, 8)

# %% [markdown]
# - There are 150 rows and 8 column are present in this dataset.

# %% [markdown]
# **6.info()**: ***summarize the dataframe (i.e shows the column_name,non_null and datatypes).***

# %%
df.info() # shows the summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  150 non-null    int64
#  1   Name       150 non-null    object
#  2   Gender     150 non-null    object
#  3   Course     150 non-null    object
#  4   Age        150 non-null    int64
#  5   Marks      150 non-null    int64
#  6   Grade      150 non-null    object
#  7   City       150 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 9.5+ KB

# %% [markdown]
# - In above StudentID, Age, Marks are integer datatypes.
# - Name, Gender, course, Grade, city have object datatypes.

# %% [markdown]
# **7.nunique()**: ***It return the total number of unique values in column.***

# %%
df.nunique() # that shows the unique values in data
# Out:
# StudentID    150
# Name          10
# Gender         2
# Course         5
# Age           13
# Marks         56
# Grade          5
# City           5
# dtype: int64

# %% [markdown]
# - There  are 150 values of total students.
# - 10 unique  names are present.
# - 2 genders are their and total 5 courses are available, 13 ages  and 56 marks,total 5 grades and 5 cities are present in this data.

# %% [markdown]
# **8.isnull().sum()** :***It check the missing values and count them.***

# %%
df.isnull().sum() # isnull() to check for missing values and sum() to get the total count of missing values
# Out:
# StudentID    0
# Name         0
# Gender       0
# Course       0
# Age          0
# Marks        0
# Grade        0
# City         0
# dtype: int64

# %% [markdown]
# - There is no missing values in the dataset.

# %%
df['Course'].nunique() # to get unique value in specific column
# Out:
# 5

# %% [markdown]
# **9.duplicated()** :***To check duplicate value in column.***

# %%
df.duplicated().sum() # shows the duplicate in dataset
# Out:
# 0

# %%
df['City'].duplicated().sum() # to check specific duplicate in column
# Out:
# 145

# %% [markdown]
# - There is 145 duplicate cities.

# %%
df.drop_duplicates(inplace=True) # to drop the duplicate

# %% [markdown]
# **10.rename()**:***To change the column name.***

# %%
df.rename(columns={'Course':'designation'},inplace=True) # rename/change the column name

# %% [markdown]
# **11.columns** :***To return the column names.***

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'designation', 'Age', 'Marks', 'Grade',
#        'City'],
#       dtype='object')

# %%
df['designation'].unique() # shows the unique values in Designation
# Out:
# array(['Data Science', 'Web Development', 'AI & ML', 'Cyber Security',
#        'Cloud Computing'], dtype=object)

# %%
df.nunique()
# Out:
# StudentID      150
# Name            10
# Gender           2
# designation      5
# Age             13
# Marks           56
# Grade            5
# City             5
# dtype: int64

# %% [markdown]
# **12.value_counts()**:***To count the unique value in each column.***

# %%
df['designation'].value_counts() # shows the value count in each category
# Out:
# designation
# Data Science       36
# Web Development    35
# AI & ML            34
# Cyber Security     25
# Cloud Computing    20
# Name: count, dtype: int64

# %% [markdown]
# - There are 36 students from Data Science course.
# - 35 students from Web developments, 34 students from AI & ML , 25 students from cyber security and 20 students from cloud computing.

# %% [markdown]
# **13.groupby()** :***To create a group. or Aggregate data by category.***

# %%
df.groupby("designation")["Marks"].mean() # to create group
# Out:
# designation
# AI & ML            67.911765
# Cloud Computing    68.450000
# Cyber Security     66.240000
# Data Science       70.888889
# Web Development    61.971429
# Name: Marks, dtype: float64

# %% [markdown]
# **14.sort_values()** :***Sorting the rows in ascending or descending oreder.***

# %%
df.sort_values(by="Marks",ascending=False) # sort the marks by ascending order
# Out:
#      StudentID   Name  Gender      designation  Age  Marks Grade       City
# 17        2018  Aarav  Female     Data Science   27    100     C    Kolkata
# 36        2037   Diya  Female  Web Development   29    100     C  Bangalore
# 10        2011  Aarav  Female     Data Science   26     99     B  Hyderabad
# 12        2013   Isha  Female  Cloud Computing   20     99     D  Bangalore
# 69        2070   Diya  Female          AI & ML   23     99     F  Hyderabad
# ..         ...    ...     ...              ...  ...    ...   ...        ...
# 62        2063  Aarav    Male  Web Development   23     42     A     Mumbai
# 128       2129  Aarav  Female  Web Development   30     41     F     Mumbai
# 45        2046  Anaya    Male          AI & ML   30     41     A    Kolkata
# 130       2131  Meera    Male  Web Development   23     40     C  Bangalore
# 107       2108  Sanya    Male     Data Science   24     40     B     Mumbai
#
# [150 rows x 8 columns]

# %% [markdown]
# **15.drop()**:***To remove row or column.***

# %%
df.drop("StudentID",axis=1,inplace=True) # drop() is used to remove the column

# %%
df.drop(0,axis=0,inplace=True)  # dropping rows using index position,axis=0 for rows

# %% [markdown]
# **16.index**:***Return the row index.***

# %%
df.index
# Out:
# RangeIndex(start=1, stop=150, step=1)

# %%
df[df['Marks'] > 90] # filtring the data where marks > 90
# Out:
#        Name  Gender      designation  Age  Marks Grade       City
# 2    Vivaan    Male  Web Development   24     98     B    Kolkata
# 5     Aarav    Male  Web Development   28     96     D     Mumbai
# 10    Aarav  Female     Data Science   26     99     B  Hyderabad
# 12     Isha  Female  Cloud Computing   20     99     D  Bangalore
# 17    Aarav  Female     Data Science   27    100     C    Kolkata
# 30    Rohan  Female     Data Science   24     92     D  Bangalore
# 36     Diya  Female  Web Development   29    100     C  Bangalore
# 46    Aryan    Male     Data Science   22     95     F  Hyderabad
# 47   Vivaan    Male  Web Development   25     91     C  Hyderabad
# 49     Isha    Male  Web Development   21     94     D  Bangalore
# 59    Anaya    Male   Cyber Security   18     95     F  Hyderabad
# 69     Diya  Female          AI & ML   23     99     F  Hyderabad
# 71    Aarav  Female  Cloud Computing   19     92     B    Kolkata
# ...

# %%
df[df['City']=='Delhi']
# Out:
#        Name  Gender      designation  Age  Marks Grade   City
# 6     Sanya    Male     Data Science   18     87     D  Delhi
# 7     Kabir    Male          AI & ML   26     86     B  Delhi
# 24    Sanya    Male          AI & ML   26     72     B  Delhi
# 33   Vivaan    Male     Data Science   24     85     B  Delhi
# 43     Diya  Female   Cyber Security   28     61     D  Delhi
# 56    Kabir    Male          AI & ML   22     54     C  Delhi
# 64    Sanya    Male   Cyber Security   20     56     C  Delhi
# 67    Kabir    Male  Web Development   25     51     F  Delhi
# 86     Diya    Male  Web Development   23     67     A  Delhi
# 99    Aarav  Female          AI & ML   19     65     A  Delhi
# 106  Vivaan  Female          AI & ML   28     68     D  Delhi
# 119   Aryan  Female          AI & ML   25     96     A  Delhi
# 134   Aarav    Male   Cyber Security   23     79     A  Delhi
# 136    Isha    Male     Data Science   21     55     B  Delhi
# ...

# %%
df[df['Marks'] > 90].shape[0]# filtering the column base on conditon and shap[0]  that count the each student
# Out:
# 21

# %% [markdown]
# **17.loc[]** :***Access by label.***

# %%
df.loc[4] # loc is use for label based indexing.returns rows with the index label 4
# Out:
# Name                     Anaya
# Gender                  Female
# designation    Web Development
# Age                         28
# Marks                       51
# Grade                        A
# City                 Hyderabad
# Name: 4, dtype: object

# %%
df.loc[:,["Name","Marks"]] # this is shows only Selected column  values
# Out:
#        Name  Marks
# 1     Aarav     42
# 2    Vivaan     98
# 3     Sanya     52
# 4     Anaya     51
# 5     Aarav     96
# ..      ...    ...
# 145   Anaya     44
# 146   Meera     57
# 147   Kabir     92
# 148   Sanya     60
# 149    Diya     44
#
# [149 rows x 2 columns]

# %% [markdown]
# **18.iloc[]** :***Access by position.***

# %%
df.iloc[3] # returns the row for the specified index position .
# Out:
# Name                     Anaya
# Gender                  Female
# designation    Web Development
# Age                         28
# Marks                       51
# Grade                        A
# City                 Hyderabad
# Name: 4, dtype: object

# %%
df.iloc[:, 0:10] # accessing the records for all the  columns with the index 0-10
# Out:
#        Name  Gender      designation  Age  Marks Grade       City
# 1     Aarav  Female     Data Science   27     42     A  Hyderabad
# 2    Vivaan    Male  Web Development   24     98     B    Kolkata
# 3     Sanya  Female  Web Development   23     52     A  Hyderabad
# 4     Anaya  Female  Web Development   28     51     A  Hyderabad
# 5     Aarav    Male  Web Development   28     96     D     Mumbai
# ..      ...     ...              ...  ...    ...   ...        ...
# 145   Anaya    Male  Cloud Computing   19     44     B  Bangalore
# 146   Meera  Female          AI & ML   18     57     D  Hyderabad
# 147   Kabir  Female  Cloud Computing   21     92     F  Bangalore
# 148   Sanya  Female   Cyber Security   26     60     D      Delhi
# 149    Diya  Female          AI & ML   24     44     F      Delhi
#
# [149 rows x 7 columns]

# %%
df['Additional_score']=df['Marks']+ 5
df['Additional_score']    # to add in 5 each marks and create new column
# Out:
# 1       47
# 2      103
# 3       57
# 4       56
# 5      101
#       ...
# 145     49
# 146     62
# 147     97
# 148     65
# 149     49
# Name: Additional_score, Length: 149, dtype: int64

# %%
df.sort_values(by="Additional_score",ascending=False)
# Out:
#       Name  Gender      designation  Age  Marks Grade       City  \
# 36    Diya  Female  Web Development   29    100     C  Bangalore
# 17   Aarav  Female     Data Science   27    100     C    Kolkata
# 69    Diya  Female          AI & ML   23     99     F  Hyderabad
# 10   Aarav  Female     Data Science   26     99     B  Hyderabad
# 131   Isha    Male     Data Science   30     99     B    Kolkata
# ..     ...     ...              ...  ...    ...   ...        ...
# 1    Aarav  Female     Data Science   27     42     A  Hyderabad
# 128  Aarav  Female  Web Development   30     41     F     Mumbai
# 45   Anaya    Male          AI & ML   30     41     A    Kolkata
# 130  Meera    Male  Web Development   23     40     C  Bangalore
# 107  Sanya    Male     Data Science   24     40     B     Mumbai
#
#      Additional_score
# 36                105
# 17                105
# 69                104
# 10                104
# 131               104
# ..                ...
# ...

# %% [markdown]
# **19.rank()** :***Rank value in a column.***

# %%
df['Additional_score'].rank(ascending=False) # rank to change position and return value
# Out:
# 1      144.5
# 2        7.0
# 3      113.0
# 4      118.5
# 5       11.0
#        ...
# 145    138.0
# 146     95.0
# 147     18.0
# 148     82.5
# 149    138.0
# Name: Additional_score, Length: 149, dtype: float64

# %% [markdown]
# **20.astype()** :***To Convert the datatypes of column.***

# %%
df['Additional_score'].astype(float) # to change data type of column
# Out:
# 1       47.0
# 2      103.0
# 3       57.0
# 4       56.0
# 5      101.0
#        ...
# 145     49.0
# 146     62.0
# 147     97.0
# 148     65.0
# 149     49.0
# Name: Additional_score, Length: 149, dtype: float64

# %% [markdown]
# **21.apply()**:***Used to apply function to each row or column.***

# %%
df['Final_Report']=df['City'].apply(lambda x : "Eligible" if x =='Mumbai' else "not eligible")  # to apply function
df['Final_Report']
# Out:
# 1      not eligible
# 2      not eligible
# 3      not eligible
# 4      not eligible
# 5          Eligible
#            ...
# 145    not eligible
# 146    not eligible
# 147    not eligible
# 148    not eligible
# 149    not eligible
# Name: Final_Report, Length: 149, dtype: object

# %%
df['Final_Result']=df['Marks'].apply(lambda x : "pass" if x >= 75 else "fail")  # to apply function
df['Final_Result']
# Out:
# 1      fail
# 2      pass
# 3      fail
# 4      fail
# 5      pass
#        ...
# 145    fail
# 146    fail
# 147    pass
# 148    fail
# 149    fail
# Name: Final_Result, Length: 149, dtype: object

# %% [markdown]
# **22.query()** :***Use sql like quries to filter data.***

# %%
df.query("designation =='Data Science' and Marks > 80") # apply query to filter data
# Out:
#        Name  Gender   designation  Age  Marks Grade       City  \
# 6     Sanya    Male  Data Science   18     87     D      Delhi
# 10    Aarav  Female  Data Science   26     99     B  Hyderabad
# 17    Aarav  Female  Data Science   27    100     C    Kolkata
# 30    Rohan  Female  Data Science   24     92     D  Bangalore
# 32   Vivaan  Female  Data Science   21     84     B  Bangalore
# 33   Vivaan    Male  Data Science   24     85     B      Delhi
# 38   Vivaan  Female  Data Science   27     83     A    Kolkata
# 40    Sanya  Female  Data Science   26     85     F  Hyderabad
# 46    Aryan    Male  Data Science   22     95     F  Hyderabad
# 104    Isha  Female  Data Science   23     97     B  Bangalore
# 117   Sanya    Male  Data Science   18     91     D  Bangalore
# 131    Isha    Male  Data Science   30     99     B    Kolkata
#
#      Additional_score  Final_Report Final_Result
# 6                  92  not eligible         pass
# ...

# %% [markdown]
# **23.pivot_table()** :***Summarize data types of column aggregation function(sum,mean,median,mode).***

# %%
df.pivot_table(values="Marks",index='designation',columns='Gender',aggfunc='sum') # to use aggregate function in pivot table
# Out:
# Gender           Female  Male
# designation
# AI & ML            1243  1066
# Cloud Computing     820   549
# Cyber Security      762   894
# Data Science       1384  1086
# Web Development     791  1378

# %%
df.pivot_table(values="Age",index='designation',columns='Gender',aggfunc='mean') # to use aggregate function in pivot table
# Out:
# Gender              Female       Male
# designation
# AI & ML          23.529412  25.000000
# Cloud Computing  22.636364  25.333333
# Cyber Security   24.500000  23.230769
# Data Science     24.052632  23.625000
# Web Development  27.307692  24.409091

# %% [markdown]
# # **Correlation**
#
# # **What is correlation ?**
# - Correlation refers to the relationship between two or more variables.
# - It measure how changes in one variable are linked to the changes in another variable.
# - It apply only numerical columns.
#
# # **Type of Correlation**
#
# **1.Positive correlation** :
# - The value range is (0-1).it indicates two variables are positively correlated.i.e one variable is increase other variable is also increase or decrease.
#
# **2.Negative correlation** :
# - value range is(-1 to 0) . it indicates the two variable are negatively correlated. if one variable is increase the other variable is decrease.
#
# **3.Zero / No correlation** :
# - value range is 0. it indicates there is no relationship between variables.

# %%
correlation_table=df[['Age','Marks']].corr()# to find correlation
print(correlation_table)
# Out:
#             Age     Marks
# Age    1.000000 -0.081903
# Marks -0.081903  1.000000

# %% [markdown]
# - In Age and Marks column there is no correlation or zero coorelation between them.
